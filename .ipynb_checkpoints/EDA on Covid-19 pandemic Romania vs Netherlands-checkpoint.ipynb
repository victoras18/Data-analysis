# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("darkgrid")

# %%
# Data URL
url_deaths_cases_daily = "https://opendata.ecdc.europa.eu/covid19/nationalcasedeath_eueea_daily_ei/csv/data.csv"
url_deaths_cases_weekly = "https://opendata.ecdc.europa.eu/covid19/nationalcasedeath/csv"

# %%
#Load daily cases
deaths_cases_daily = pd.read_csv(url_deaths_cases_daily)
deaths_cases_daily['dateRep'] = pd.to_datetime(deaths_cases_daily['dateRep']).dt.strftime('%d-%m-%Y')
deaths_cases_daily.head()
# Out:
#       dateRep  day  month  year  cases  deaths countriesAndTerritories geoId  \
# 0  23-04-2021   23      4  2021   2347      25                 Austria    AT
# 1  22-04-2021   22      4  2021   2377      40                 Austria    AT
# 2  21-04-2021   21      4  2021   2005      27                 Austria    AT
# 3  20-04-2021   20      4  2021   1792      32                 Austria    AT
# 4  19-04-2021   19      4  2021   2159      34                 Austria    AT
#
#   countryterritoryCode  popData2020 continentExp
# 0                  AUT      8901064       Europe
# 1                  AUT      8901064       Europe
# 2                  AUT      8901064       Europe
# 3                  AUT      8901064       Europe
# 4                  AUT      8901064       Europe

# %%
#Generate single country dataframe
def country_df(country):
    df = deaths_cases_daily[deaths_cases_daily["geoId"]==country].copy()
    df.reset_index(drop=True, inplace= True)
    df.sort_index(ascending=False, inplace=True)
    df.reset_index(drop=True, inplace= True)
    df.drop(index=df.index[0], axis=0, inplace=True)
    return df

# %%
def plot_cases(df):
    plt.figure(figsize=(15,4))
    sns.barplot(x='dateRep',y='cases', data=df, color="cornflowerblue")
    plt.xlabel('Date', fontsize=15)
    plt.ylabel('Cases', fontsize=15)
    plt.xticks(fontsize=12, rotation=70)
    plt.title("{} daily COVID-19 cases".format(df['countriesAndTerritories'].iloc[0]),fontsize=18)
    plt.show()

# %%
Romania_daily = country_df('RO')
Netherlands_daily = country_df('NL')

# %%
plot_cases(Romania_daily)
plot_cases(Netherlands_daily)
